# %%
import pandas as pd

# %% [markdown]
# # Attributes on a dataframe

# %%
names=['Aravind','Shweta','Suraj','Rajesh','Priya','Vaishali','Tejasvi','Surendra','Pragya','Joy']
ID=[101,102,103,104,105,106,107,108,109,110]
city=['Delhi','Agra','Chandigarh','Pune','Hyderabd','Bangalore','Mumbai','Pune','Dehradun','Chennai']

# %%
df=pd.DataFrame({'Name':names,'ID':ID,'City':city})
df
# Out:
#        Name   ID        City
# 0   Aravind  101       Delhi
# 1    Shweta  102        Agra
# 2     Suraj  103  Chandigarh
# 3    Rajesh  104        Pune
# 4     Priya  105    Hyderabd
# 5  Vaishali  106   Bangalore
# 6   Tejasvi  107      Mumbai
# 7  Surendra  108        Pune
# 8    Pragya  109    Dehradun
# 9       Joy  110     Chennai

# %% [markdown]
# ### shape

# %%
df.shape
# Out:
# (10, 3)

# %% [markdown]
# ### size

# %%
df.size
# Out:
# 30

# %%
len(df)
# Out:
# 10

# %% [markdown]
# ### dtypes

# %%
df.dtypes
# Out:
# Name    object
# ID       int64
# City    object
# dtype: object

# %% [markdown]
# ### ndim

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ### index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# ### values

# %%
df.values
# Out:
# array([['Aravind', 101, 'Delhi'],
#        ['Shweta', 102, 'Agra'],
#        ['Suraj', 103, 'Chandigarh'],
#        ['Rajesh', 104, 'Pune'],
#        ['Priya', 105, 'Hyderabd'],
#        ['Vaishali', 106, 'Bangalore'],
#        ['Tejasvi', 107, 'Mumbai'],
#        ['Surendra', 108, 'Pune'],
#        ['Pragya', 109, 'Dehradun'],
#        ['Joy', 110, 'Chennai']], dtype=object)

# %% [markdown]
# ### columns

# %%
df.columns
# Out:
# Index(['Name', 'ID', 'City'], dtype='object')

# %% [markdown]
# # Indexing and Slicing of a dataframe

# %% [markdown]
# # Indexing

# %% [markdown]
# - 1- Implicit index (Python defined)- iloc
# - 2- Explicit index (Labels)- loc

# %%
df
# Out:
#        Name   ID        City
# 0   Aravind  101       Delhi
# 1    Shweta  102        Agra
# 2     Suraj  103  Chandigarh
# 3    Rajesh  104        Pune
# 4     Priya  105    Hyderabd
# 5  Vaishali  106   Bangalore
# 6   Tejasvi  107      Mumbai
# 7  Surendra  108        Pune
# 8    Pragya  109    Dehradun
# 9       Joy  110     Chennai

# %%
df.iloc[0]
# Out:
# Name    Aravind
# ID          101
# City      Delhi
# Name: 0, dtype: object

# %%
df.index=df.ID

# %%
df
# Out:
#          Name   ID        City
# ID
# 101   Aravind  101       Delhi
# 102    Shweta  102        Agra
# 103     Suraj  103  Chandigarh
# 104    Rajesh  104        Pune
# 105     Priya  105    Hyderabd
# 106  Vaishali  106   Bangalore
# 107   Tejasvi  107      Mumbai
# 108  Surendra  108        Pune
# 109    Pragya  109    Dehradun
# 110       Joy  110     Chennai

# %%
# Fetch the first row
df.iloc[[0]]
# Out:
#         Name   ID   City
# ID
# 101  Aravind  101  Delhi

# %%
df.loc[[101]]
# Out:
#         Name   ID   City
# ID
# 101  Aravind  101  Delhi

# %%
# Fetch the last row
df.iloc[[-1]]
# Out:
#     Name   ID     City
# ID
# 110  Joy  110  Chennai

# %%
df.iloc[3,0]
# Out:
# 'Rajesh'

# %%
df.loc[104,'Name']
# Out:
# 'Rajesh'

# %% [markdown]
# # Slicing

# %%
df
# Out:
#          Name   ID        City
# ID
# 101   Aravind  101       Delhi
# 102    Shweta  102        Agra
# 103     Suraj  103  Chandigarh
# 104    Rajesh  104        Pune
# 105     Priya  105    Hyderabd
# 106  Vaishali  106   Bangalore
# 107   Tejasvi  107      Mumbai
# 108  Surendra  108        Pune
# 109    Pragya  109    Dehradun
# 110       Joy  110     Chennai

# %%
# First two rows

df.iloc[0:2]
# Out:
#         Name   ID   City
# ID
# 101  Aravind  101  Delhi
# 102   Shweta  102   Agra

# %%
df.loc[101:102]
# Out:
#         Name   ID   City
# ID
# 101  Aravind  101  Delhi
# 102   Shweta  102   Agra

# %%
# First three rows and the first two columns

df.iloc[0:3,0:2]
# Out:
#         Name   ID
# ID
# 101  Aravind  101
# 102   Shweta  102
# 103    Suraj  103

# %%
df
# Out:
#          Name   ID        City
# ID
# 101   Aravind  101       Delhi
# 102    Shweta  102        Agra
# 103     Suraj  103  Chandigarh
# 104    Rajesh  104        Pune
# 105     Priya  105    Hyderabd
# 106  Vaishali  106   Bangalore
# 107   Tejasvi  107      Mumbai
# 108  Surendra  108        Pune
# 109    Pragya  109    Dehradun
# 110       Joy  110     Chennai

# %%
# Reverse the rows

# %%
df.iloc[::-1]
# Out:
#          Name   ID        City
# ID
# 110       Joy  110     Chennai
# 109    Pragya  109    Dehradun
# 108  Surendra  108        Pune
# 107   Tejasvi  107      Mumbai
# 106  Vaishali  106   Bangalore
# 105     Priya  105    Hyderabd
# 104    Rajesh  104        Pune
# 103     Suraj  103  Chandigarh
# 102    Shweta  102        Agra
# 101   Aravind  101       Delhi

# %%
df.loc[110:101:-1]
# Out:
#          Name   ID        City
# ID
# 110       Joy  110     Chennai
# 109    Pragya  109    Dehradun
# 108  Surendra  108        Pune
# 107   Tejasvi  107      Mumbai
# 106  Vaishali  106   Bangalore
# 105     Priya  105    Hyderabd
# 104    Rajesh  104        Pune
# 103     Suraj  103  Chandigarh
# 102    Shweta  102        Agra
# 101   Aravind  101       Delhi

# %%
df
# Out:
#          Name   ID        City
# ID
# 101   Aravind  101       Delhi
# 102    Shweta  102        Agra
# 103     Suraj  103  Chandigarh
# 104    Rajesh  104        Pune
# 105     Priya  105    Hyderabd
# 106  Vaishali  106   Bangalore
# 107   Tejasvi  107      Mumbai
# 108  Surendra  108        Pune
# 109    Pragya  109    Dehradun
# 110       Joy  110     Chennai

# %%
# Reverse the columns
df.iloc[::,::-1]
# Out:
#            City   ID      Name
# ID
# 101       Delhi  101   Aravind
# 102        Agra  102    Shweta
# 103  Chandigarh  103     Suraj
# 104        Pune  104    Rajesh
# 105    Hyderabd  105     Priya
# 106   Bangalore  106  Vaishali
# 107      Mumbai  107   Tejasvi
# 108        Pune  108  Surendra
# 109    Dehradun  109    Pragya
# 110     Chennai  110       Joy

# %%
# Reverse the rows and the columns both

df.iloc[::-1,::-1]
# Out:
#            City   ID      Name
# ID
# 110     Chennai  110       Joy
# 109    Dehradun  109    Pragya
# 108        Pune  108  Surendra
# 107      Mumbai  107   Tejasvi
# 106   Bangalore  106  Vaishali
# 105    Hyderabd  105     Priya
# 104        Pune  104    Rajesh
# 103  Chandigarh  103     Suraj
# 102        Agra  102    Shweta
# 101       Delhi  101   Aravind

# %% [markdown]
# # How to access a column

# %%
# df['col_name']
# df.col_name

# %%
df
# Out:
#          Name   ID        City
# ID
# 101   Aravind  101       Delhi
# 102    Shweta  102        Agra
# 103     Suraj  103  Chandigarh
# 104    Rajesh  104        Pune
# 105     Priya  105    Hyderabd
# 106  Vaishali  106   Bangalore
# 107   Tejasvi  107      Mumbai
# 108  Surendra  108        Pune
# 109    Pragya  109    Dehradun
# 110       Joy  110     Chennai

# %%
df[['Name']]
# Out:
#          Name
# ID
# 101   Aravind
# 102    Shweta
# 103     Suraj
# 104    Rajesh
# 105     Priya
# 106  Vaishali
# 107   Tejasvi
# 108  Surendra
# 109    Pragya
# 110       Joy

# %%
df.Name
# Out:
# ID
# 101     Aravind
# 102      Shweta
# 103       Suraj
# 104      Rajesh
# 105       Priya
# 106    Vaishali
# 107     Tejasvi
# 108    Surendra
# 109      Pragya
# 110         Joy
# Name: Name, dtype: object

# %%
df[['Name','City']]
# Out:
#          Name        City
# ID
# 101   Aravind       Delhi
# 102    Shweta        Agra
# 103     Suraj  Chandigarh
# 104    Rajesh        Pune
# 105     Priya    Hyderabd
# 106  Vaishali   Bangalore
# 107   Tejasvi      Mumbai
# 108  Surendra        Pune
# 109    Pragya    Dehradun
# 110       Joy     Chennai

# %%
df[['City','Name']]
# Out:
#            City      Name
# ID
# 101       Delhi   Aravind
# 102        Agra    Shweta
# 103  Chandigarh     Suraj
# 104        Pune    Rajesh
# 105    Hyderabd     Priya
# 106   Bangalore  Vaishali
# 107      Mumbai   Tejasvi
# 108        Pune  Surendra
# 109    Dehradun    Pragya
# 110     Chennai       Joy

# %%
df.iloc[0:4][['ID','Name']]
# Out:
#       ID     Name
# ID
# 101  101  Aravind
# 102  102   Shweta
# 103  103    Suraj
# 104  104   Rajesh

# %%
df.index=['emp_'+str(i) for i in range(1,11)]

# %%
df
# Out:
#             Name   ID        City
# emp_1    Aravind  101       Delhi
# emp_2     Shweta  102        Agra
# emp_3      Suraj  103  Chandigarh
# emp_4     Rajesh  104        Pune
# emp_5      Priya  105    Hyderabd
# emp_6   Vaishali  106   Bangalore
# emp_7    Tejasvi  107      Mumbai
# emp_8   Surendra  108        Pune
# emp_9     Pragya  109    Dehradun
# emp_10       Joy  110     Chennai

# %%
df.iloc[0:3]
# Out:
#           Name   ID        City
# emp_1  Aravind  101       Delhi
# emp_2   Shweta  102        Agra
# emp_3    Suraj  103  Chandigarh

# %%
df.loc['emp_1':'emp_3']
# Out:
#           Name   ID        City
# emp_1  Aravind  101       Delhi
# emp_2   Shweta  102        Agra
# emp_3    Suraj  103  Chandigarh

# %%
df.iloc[0:2,0:2]
# Out:
#           Name   ID
# emp_1  Aravind  101
# emp_2   Shweta  102

# %%
df.loc['emp_1':'emp_2','Name']
# Out:
# emp_1    Aravind
# emp_2     Shweta
# Name: Name, dtype: object

# %% [markdown]
# # How to import a csv file or an excel file

# %%
# pd.read_csv(path)
# pd.read_excel(path)

# %%
pd.read_csv("C:\\Users\\Dell\\OneDrive\\Desktop\\Data Science\\Learn Bay Classes\\Practice Datasets\\Titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv("C:/Users/Dell/OneDrive/Desktop/Data Science/Learn Bay Classes/Practice Datasets/Titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ti=pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Data Science\Learn Bay Classes\Practice Datasets\Titanic.csv")
ti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ti.shape
# Out:
# (891, 12)

# %%
ti.size*
# Out:
# 10692

# %%
891*12
# Out:
# 10692

# %%
len(ti)
# Out:
# 891

# %%
ti.ndim
# Out:
# 2

# %%
ti.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
ti.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
ti.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
ti.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Functions on dataframe

# %% [markdown]
# # head()

# %% [markdown]
# - It reurns the first 5 rows from the dataframe.

# %%
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ti.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # tail()

# %% [markdown]
# - It returns the last 5 rows from the dataframe.

# %%
ti.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
ti.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # info()

# %% [markdown]
# - It returns some basic information about the dataframe.

# %%
ti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# nan- missing value

# %% [markdown]
# # describe()

# %% [markdown]
# - It returns the statistical summary of the numeric columns

# %%
ti.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Get the 5th percentile, 10th percentile and 99th percentile values

# %%
ti.describe(percentiles=[0.01,.05,.1,.99])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 1%        9.900000    0.000000    1.000000    1.000000    0.000000
# 5%       45.500000    0.000000    1.000000    4.000000    0.000000
# 10%      90.000000    0.000000    1.000000   14.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 99%     882.100000    1.000000    3.000000   65.870000    5.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 1%       0.000000    0.000000
# 5%       0.000000    7.225000
# ...

# %% [markdown]
# # Getting the percentile values

# %%
import numpy as np

# %%
# np.percentile()
# df.col.quantile()

# %%
np.percentile(ti.Fare,[25,75,99,100])
# Out:
# array([  7.9104 ,  31.     , 249.00622, 512.3292 ])

# %%
ti.Age.quantile([0.25,0.50,0.75,0.99])
# Out:
# 0.25    20.125
# 0.50    28.000
# 0.75    38.000
# 0.99    65.870
# Name: Age, dtype: float64

# %% [markdown]
# # nunique()

# %% [markdown]
# - It returns the number of unique values in each column in a dataframe.

# %%
ti.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # unique()

# %% [markdown]
# - It returns the name of the unique values in a particular column.

# %%
ti.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
ti['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
ti.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
ti.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # value_counts()

# %% [markdown]
# - It returns the counts of each unique value inside a column.

# %%
ti.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
549+342
# Out:
# 891

# %%
ti.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
ti.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# # Handliling the null values

# %%
# isna()
# isnull()

# %%
ti.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ti.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ti.Age.isna().sum()
# Out:
# 177

# %%
ti['Age'].isna().sum()
# Out:
# 177

# %%
ti.Cabin.isna().sum()
# Out:
# 687

# %%
ti['Cabin'].isna().sum()
# Out:
# 687

# %% [markdown]
# # Filling the null values

# %%
# df.col.fillna(value)
# - It does not make the changes in the exisiting column.

# %%
# Fill the null values by the mean value in Age column

# %%
ti.Age.fillna(ti.Age.mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
ti.Age.isna().sum()
# Out:
# 177

# %%
ti.Age.fillna(ti.Age.mean(),inplace=True)

# %%
ti.Age.isna().sum()
# Out:
# 0

# %%
ti.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Dropping the null values

# %%
# df.dropna()
# - It removes all the rows that have atleast 1 Nan value.

# %%
ti=pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Data Science\Learn Bay Classes\Practice Datasets\Titanic.csv")
ti.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
ti.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ti.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
891-183
# Out:
# 708

# %%
ti['Dummy']=np.nan

# %%
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Dummy
# 0      0         A/5 21171   7.2500   NaN        S    NaN
# 1      0          PC 17599  71.2833   C85        C    NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S    NaN
# 3      0            113803  53.1000  C123        S    NaN
# ...

# %%
ti.dropna()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Dummy]
# Index: []

# %%
ti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ti.dropna(inplace=True)
# ti=ti.dropna()

# %%
ti
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Dummy]
# Index: []

# %%
ti=pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Data Science\Learn Bay Classes\Practice Datasets\Titanic.csv")
ti.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
ti.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ti.iloc[0:10]=np.nan

# %%
ti.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           NaN       NaN     NaN
# 1           NaN       NaN     NaN
# 2           NaN       NaN     NaN
# 3           NaN       NaN     NaN
# 4           NaN       NaN     NaN
# 5           NaN       NaN     NaN
# 6           NaN       NaN     NaN
# 7           NaN       NaN     NaN
# 8           NaN       NaN     NaN
# 9           NaN       NaN     NaN
# 10         11.0       1.0     3.0
# 11         12.0       1.0     1.0
# 12         13.0       0.0     3.0
# 13         14.0       0.0     3.0
# 14         15.0       0.0     3.0
# 15         16.0       1.0     2.0
# 16         17.0       0.0     3.0
# 17         18.0       1.0     2.0
# 18         19.0       0.0     3.0
# 19         20.0       1.0     3.0
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                                 NaN     NaN   NaN    NaN
# 1                                                 NaN     NaN   NaN    NaN
# ...

# %%
# rows- all values are null values
# rows- few null values or no null values

# %%
ti=ti.dropna(how='all')

# %%
ti
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 10          11.0       1.0     3.0           Sandstrom, Miss. Marguerite Rut
# 11          12.0       1.0     1.0                  Bonnell, Miss. Elizabeth
# 12          13.0       0.0     3.0            Saundercock, Mr. William Henry
# 13          14.0       0.0     3.0               Andersson, Mr. Anders Johan
# 14          15.0       0.0     3.0      Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                       ...
# 886        887.0       0.0     2.0                     Montvila, Rev. Juozas
# 887        888.0       1.0     1.0              Graham, Miss. Margaret Edith
# 888        889.0       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"
# 889        890.0       1.0     1.0                     Behr, Mr. Karl Howell
# 890        891.0       0.0     3.0                       Dooley, Mr. Patrick
#
# ...

# %%
# ti.dropna(thresh=2)
# Escape all the rows those have atleast two non null values

# %%
ti.dropna(thresh=12)
# Out:
#      PassengerId  Survived  Pclass  \
# 10          11.0       1.0     3.0
# 11          12.0       1.0     1.0
# 21          22.0       1.0     2.0
# 23          24.0       1.0     1.0
# 27          28.0       0.0     1.0
# ..           ...       ...     ...
# 871        872.0       1.0     1.0
# 872        873.0       0.0     1.0
# 879        880.0       1.0     1.0
# 887        888.0       1.0     1.0
# 889        890.0       1.0     1.0
#
#                                                  Name     Sex   Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0    1.0
# 11                           Bonnell, Miss. Elizabeth  female  58.0    0.0
# 21                              Beesley, Mr. Lawrence    male  34.0    0.0
# 23                       Sloper, Mr. William Thompson    male  28.0    0.0
# 27                     Fortune, Mr. Charles Alexander    male  19.0    3.0
# ..                                                ...     ...   ...    ...
# ...

# %%
# [10,20,nan, 50]
# [nan,50,nan,20]
# [10,20,30,40]

# %%
ti
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 10          11.0       1.0     3.0           Sandstrom, Miss. Marguerite Rut
# 11          12.0       1.0     1.0                  Bonnell, Miss. Elizabeth
# 12          13.0       0.0     3.0            Saundercock, Mr. William Henry
# 13          14.0       0.0     3.0               Andersson, Mr. Anders Johan
# 14          15.0       0.0     3.0      Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                       ...
# 886        887.0       0.0     2.0                     Montvila, Rev. Juozas
# 887        888.0       1.0     1.0              Graham, Miss. Margaret Edith
# 888        889.0       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"
# 889        890.0       1.0     1.0                     Behr, Mr. Karl Howell
# 890        891.0       0.0     3.0                       Dooley, Mr. Patrick
#
# ...

# %%
ti.iloc[0:5:1,0:5:2]
# Out:
#     PassengerId  Pclass     Sex
# 10         11.0     3.0  female
# 11         12.0     1.0  female
# 12         13.0     3.0    male
# 13         14.0     3.0    male
# 14         15.0     3.0  female
